# %%
# %load_ext autoreload
# %autoreload 2

import torch
import utils

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
"cuda" if torch.cuda.is_available() else "cpu"

code_names = ['code_1', 'code_2', 'code_3', 'code_4', 'code_mix']
train_code = code_names[4]
dir_name = 'ep500_dp01_2000_SNR2-7_FM150'
result_dir = utils.get_rec_dir(dir_name)


train_range = range(2,4)
test_range = range(1,11)

# %% [markdown]
# ## ACC table

# %%
utils.draw_ACC(result_dir, code_names, range(2,8), test_range)

# %% [markdown]
# ## BER

# %% [markdown]
# ### BER CNN

# %%
utils.draw_BER_single(result_dir, 3, code_names[4], range(2,8), test_range, train_code)
# Out:
# CNN 2dB: [0.1538300067, 0.1416991651, 0.1352458298, 0.1331599951, 0.1317116618, 0.1308799982, 0.13065584, 0.1311083287, 0.1307916641, 0.1310491711]
# CNN 3dB: [0.1462374926, 0.1326249987, 0.1254325062, 0.1228350028, 0.1217341647, 0.1209591627, 0.1209841669, 0.1211491674, 0.1211249977, 0.1210766658]
# CNN 4dB: [0.1561566591, 0.1424358338, 0.1344158351, 0.1311499923, 0.1300741732, 0.1293183267, 0.1297183335, 0.1295141727, 0.1289224923, 0.1293524951]
# CNN 5dB: [0.1538191736, 0.1396266669, 0.1314650029, 0.1283241659, 0.1272358298, 0.126077503, 0.1263391674, 0.1261333376, 0.1263474971, 0.1264841706]
# CNN 6dB: [0.1561975032, 0.1418150067, 0.1343133301, 0.1313550025, 0.1297875047, 0.129264161, 0.1292266697, 0.1290583313, 0.1290016621, 0.1292500049]
# CNN 7dB: [0.1498633325, 0.1353033334, 0.1276291609, 0.1243266687, 0.123044163, 0.1223049983, 0.1225674972, 0.1223450005, 0.122406669, 0.1230041683]

# %% [markdown]
# ### BER CCNN_T

# %%
utils.draw_BER_single(result_dir, 5, code_names[4], range(2,8), test_range, train_code)
# Out:
# CCNN_T 2dB: [0.1364624947, 0.1293933392, 0.1259375066, 0.1240049973, 0.123650834, 0.12359, 0.123163335, 0.1230574995, 0.123240836, 0.1230666637]
# CCNN_T 3dB: [0.1185574979, 0.1100216657, 0.1055208296, 0.1035783365, 0.1030133367, 0.1028100029, 0.1026933342, 0.1025133356, 0.1022650003, 0.1027616635]
# CCNN_T 4dB: [0.1128858328, 0.1029516682, 0.0981424972, 0.095828332, 0.0955208316, 0.0948991701, 0.0946725011, 0.0948883295, 0.0945116654, 0.0944600031]
# CCNN_T 5dB: [0.1241916642, 0.1147925034, 0.1094683334, 0.108070001, 0.1068666652, 0.1068274975, 0.1068641692, 0.1064608321, 0.1066024974, 0.1066191643]
# CCNN_T 6dB: [0.1131041646, 0.1035349965, 0.0987808332, 0.096479997, 0.0958633348, 0.0954266638, 0.0952741653, 0.0949375033, 0.0951983333, 0.0951966643]
# CCNN_T 7dB: [0.1168200001, 0.1072158366, 0.1023991629, 0.1004433334, 0.0994374976, 0.0992033333, 0.0990091637, 0.099074997, 0.0992375016, 0.0988691673]

# %% [markdown]
# ### BER CCNN_J1

# %%
utils.draw_BER_single(result_dir, 6, code_names[4], range(2,8), test_range, train_code)
# Out:
# CCNN_J1 2dB: [0.1353641599, 0.1232766658, 0.1164774969, 0.114138335, 0.1131483316, 0.1124108359, 0.1125933304, 0.1125933304, 0.1123083308, 0.1126350015]
# CCNN_J1 3dB: [0.1297566593, 0.1162583306, 0.1087883338, 0.1054041684, 0.1042991653, 0.103548333, 0.1039541662, 0.1038400009, 0.1039350033, 0.1042533368]
# CCNN_J1 4dB: [0.141354993, 0.1270608306, 0.1197450012, 0.1164383367, 0.1154516637, 0.1149108335, 0.1148691699, 0.1146258339, 0.1148741692, 0.1147183329]
# CCNN_J1 5dB: [0.1453791708, 0.1311591715, 0.1238258332, 0.1205308363, 0.1191658303, 0.118885003, 0.1188541651, 0.1190483347, 0.1189450026, 0.1189175025]
# CCNN_J1 6dB: [0.1431283355, 0.1288683265, 0.1209783331, 0.1177574992, 0.1162249967, 0.1156366691, 0.1156608313, 0.1159308329, 0.1155441627, 0.1157133356]
# CCNN_J1 7dB: [0.1484375, 0.1344291717, 0.1270000041, 0.1242674962, 0.1226266697, 0.1221375018, 0.1218400002, 0.122131668, 0.1219924986, 0.122209169]

# %% [markdown]
# ### CCNN_J2

# %%
utils.draw_BER_single(result_dir, 8, code_names[4], range(2,8), test_range, train_code)
# Out:
# CCNN_J2 2dB: [0.1359149963, 0.1236116663, 0.1164316684, 0.114334166, 0.1132308319, 0.1125700027, 0.1127858311, 0.1124133319, 0.1125150025, 0.1127233356]
# CCNN_J2 3dB: [0.1539216638, 0.1424066722, 0.1355825067, 0.133147493, 0.1323675066, 0.1314133257, 0.1314675063, 0.131948337, 0.1313333362, 0.131812498]
# CCNN_J2 4dB: [0.1289374977, 0.1141516641, 0.1060241684, 0.102791667, 0.101608336, 0.1008825004, 0.1007933319, 0.1008225009, 0.1004924998, 0.1010116637]
# CCNN_J2 5dB: [0.1393716633, 0.125180006, 0.1172516644, 0.1143750027, 0.1128158346, 0.1121383309, 0.1119341627, 0.1121599972, 0.1125191674, 0.1121616662]
# CCNN_J2 6dB: [0.1426483393, 0.1280858368, 0.1206408367, 0.1178425029, 0.1161108315, 0.1158558354, 0.1152683347, 0.1155975014, 0.1158441678, 0.1155616641]
# CCNN_J2 7dB: [0.1492425054, 0.1347641647, 0.1274666637, 0.1239475012, 0.1224408299, 0.1222666651, 0.1223491654, 0.1218625009, 0.122058332, 0.1224391684]

# %% [markdown]
# ### CCNN_G1

# %%
utils.draw_BER_single(result_dir, 7, code_names[4], range(2,8), test_range, train_code)
# Out:
# CCNN_G1 2dB: [0.1390475035, 0.1242316663, 0.1164041683, 0.1129983366, 0.1117308363, 0.1111391634, 0.1113441661, 0.110999167, 0.1112158298, 0.111194998]
# CCNN_G1 3dB: [0.1508708298, 0.1361725032, 0.1283791661, 0.1254316717, 0.1237649992, 0.1234633327, 0.1234200001, 0.123165831, 0.1230250001, 0.1231808364]
# CCNN_G1 4dB: [0.1551758349, 0.1397208273, 0.131780833, 0.1278033257, 0.1266291738, 0.1263124943, 0.1257150024, 0.1261633337, 0.1262091696, 0.1259158403]
# CCNN_G1 5dB: [0.1366841644, 0.1183508337, 0.1083175018, 0.1040574983, 0.1022166684, 0.1018766686, 0.1021424979, 0.1016575024, 0.1014975011, 0.1018141657]
# CCNN_G1 6dB: [0.1408791691, 0.1243858337, 0.114729166, 0.1107458323, 0.1093050018, 0.1088524982, 0.1086216643, 0.108630836, 0.1088783294, 0.1089174971]
# CCNN_G1 7dB: [0.1425166726, 0.1255016625, 0.1155683324, 0.1120758355, 0.1104258299, 0.1099308357, 0.1097291633, 0.1098991632, 0.1097158343, 0.1098858342]

# %% [markdown]
# ### BER CCNN_G2

# %%
utils.draw_BER_single(result_dir, 9, code_names[4], range(2,8), test_range, train_code)
# Out:
# CCNN_G2 2dB: [0.1521950066, 0.1385249943, 0.1311483383, 0.1283874959, 0.1267916709, 0.1265933365, 0.1265249997, 0.1264366657, 0.1264533401, 0.1265275031]
# CCNN_G2 3dB: [0.1521741599, 0.1374816597, 0.1289674938, 0.1259816736, 0.1241749972, 0.1239033341, 0.1235433295, 0.1237883344, 0.1240374967, 0.1237016693]
# CCNN_G2 4dB: [0.1445941627, 0.127744168, 0.1190916672, 0.1152525023, 0.1138983294, 0.1130116656, 0.1127166674, 0.1128541678, 0.113167502, 0.1126774997]
# CCNN_G2 5dB: [0.157447502, 0.1413058341, 0.1322483271, 0.1279033273, 0.126488328, 0.1260624975, 0.1260599941, 0.1255474985, 0.125319168, 0.125682503]
# CCNN_G2 6dB: [0.1425641626, 0.1253399998, 0.1157666668, 0.1118991673, 0.1095891669, 0.109419167, 0.1094183326, 0.1088883355, 0.1094766632, 0.1090966687]
# CCNN_G2 7dB: [0.151109159, 0.1355600059, 0.1266933382, 0.1224749982, 0.1211591661, 0.1208333299, 0.1209533364, 0.1204566658, 0.1202641651, 0.1206666678]

# %%
utils.draw_BER_single_combine(result_dir, code_names[4], range(2,8), test_range, train_code)
# Out:
# CCNN_P 2dB: [0.3256649971, 0.3218758404, 0.3204774857, 0.3190766573, 0.3196008205, 0.3191950023, 0.3194833398, 0.3190299869, 0.3195466697, 0.3182100058]
# CCNN_P 3dB: [0.1369166672, 0.1197233349, 0.1094633341, 0.1061533317, 0.104748331, 0.1043516695, 0.1040641665, 0.103928335, 0.1036249995, 0.1041266695]
# CCNN_P 4dB: [0.1324300021, 0.1126300022, 0.1025549993, 0.097345002, 0.0966441631, 0.0958241671, 0.095449999, 0.0956799984, 0.0952349976, 0.0952258334]
# CCNN_P 5dB: [0.1424716711, 0.1241158321, 0.1137558296, 0.109875001, 0.107615836, 0.1076483354, 0.1074725017, 0.1071066633, 0.1072491631, 0.1072425023]
# CCNN_P 6dB: [0.1333183348, 0.1140141636, 0.1034125015, 0.0985499993, 0.0969316661, 0.0961258337, 0.0960424989, 0.0956974998, 0.0958616659, 0.0958758295]
# CCNN_P 7dB: [0.137349993, 0.1179433316, 0.1075116694, 0.1028183326, 0.1009249985, 0.1005258337, 0.1000441685, 0.1002083346, 0.1003958359, 0.1001024991]

# %%
utils.draw_BER_compare_multi(result_dir, 3, 5, code_names[4], range(3,4), test_range, train_code)
# Out:
# CNN 3dB: [0.1462374926, 0.1326249987, 0.1254325062, 0.1228350028, 0.1217341647, 0.1209591627, 0.1209841669, 0.1211491674, 0.1211249977, 0.1210766658]
# CCNN_T 3dB: [0.1185574979, 0.1100216657, 0.1055208296, 0.1035783365, 0.1030133367, 0.1028100029, 0.1026933342, 0.1025133356, 0.1022650003, 0.1027616635]
# CCNN_P 3dB: [0.1369166672, 0.1197233349, 0.1094633341, 0.1061533317, 0.104748331, 0.1043516695, 0.1040641665, 0.103928335, 0.1036249995, 0.1041266695]
# CCNN_J1 3dB: [0.1297566593, 0.1162583306, 0.1087883338, 0.1054041684, 0.1042991653, 0.103548333, 0.1039541662, 0.1038400009, 0.1039350033, 0.1042533368]
# CCNN_G1 3dB: [0.1508708298, 0.1361725032, 0.1283791661, 0.1254316717, 0.1237649992, 0.1234633327, 0.1234200001, 0.123165831, 0.1230250001, 0.1231808364]
# CCNN_J2 3dB: [0.1539216638, 0.1424066722, 0.1355825067, 0.133147493, 0.1323675066, 0.1314133257, 0.1314675063, 0.131948337, 0.1313333362, 0.131812498]
# CCNN_G2 3dB: [0.1521741599, 0.1374816597, 0.1289674938, 0.1259816736, 0.1241749972, 0.1239033341, 0.1235433295, 0.1237883344, 0.1240374967, 0.1237016693]
#
# Compare CNN vs CCNN_T: ['18.93%', '17.04%', '15.87%', '15.68%', '15.38%', '15.0%', '15.12%', '15.38%', '15.57%', '15.13%']
# Compare CNN vs CCNN_P: ['6.37%', '9.73%', '12.73%', '13.58%', '13.95%', '13.73%', '13.99%', '14.21%', '14.45%', '14.0%']
# Compare CNN vs CCNN_J1: ['11.27%', '12.34%', '13.27%', '14.19%', '14.32%', '14.39%', '14.08%', '14.29%', '14.19%', '13.89%']
# Compare CNN vs CCNN_J2: ['-5.25%', '-7.38%', '-8.09%', '-8.4%', '-8.73%', '-8.64%', '-8.67%', '-8.91%', '-8.43%', '-8.87%']
# Compare CNN vs CCNN_G1: ['-3.17%', '-2.67%', '-2.35%', '-2.11%', '-1.67%', '-2.07%', '-2.01%', '-1.66%', '-1.57%', '-1.74%']
# Compare CNN vs CCNN_G2: ['-4.06%', '-3.66%', '-2.82%', '-2.56%', '-2.01%', '-2.43%', '-2.12%', '-2.18%', '-2.4%', '-2.17%']
# Compare CNN vs uncoded: ['61.64%', '71.74%', '81.71%', '89.85%', '94.99%', '98.06%', '99.37%', '99.87%', '99.97%', '100.0%']
# Compare CNN vs hard: ['45.72%', '69.79%', '86.83%', '96.4%', '98.94%', '99.67%', '99.91%', '100.0%', '100.0%', '100.0%']

# %% [markdown]
# ## Loss

# %% [markdown]
# ### Classifier Loss

# %%
utils.draw_multiple_classifier_loss(result_dir, range(2,8))

# %% [markdown]
# ### CNN Loss

# %%
utils.draw_multiple_decoder_loss(result_dir, 3, range(2,8))

# %% [markdown]
# ### CCNN_G1 Loss

# %%
utils.draw_gumbel_classifier_loss(result_dir, range(2,8), 1)

# %% [markdown]
# ### CCNN_G2 Loss

# %%
utils.draw_gumbel_classifier_loss(result_dir, range(2,8), 2)
